# %%
import pygame, sys
from pygame.draw import *


pygame.init()

FPS = 30
screen = pygame.display.set_mode((1500, 1000))
screen.fill((255, 160, 122))


black=(0,0,0)
white=(255,255,255)
green=(0,100,0)

#k - масштабный фактор
#x,y - координаты бамбука
def bambuk(x,y,k):

    #стебль(центральный)
        polygon(screen, green, [(x,y), (x+44/k,y),
                               (x+44/k,y-150/k), (x,y-150/k)])
        polygon(screen, green, [(x,y-160/k), (x+44/k,y-160/k),
                               (x+44/k,y-310/k), (x,y-310/k)])
        polygon(screen, green, [(x+42/k,y-435/k), (x+72/k, y-435/k),
                               (x+37/k,y-320/k), (x+7/k,y-320/k)])
        polygon(screen, green, [(x+92/k,y-505/k), (x+112/k, y-505/k),
                               (x+67/k,y-445/k), (x+47/k,y-445/k)])

    #ветки(центральные)
        pygame.draw.arc(screen, green, (int(x+52/k), int(y-385/k), int(200/k), int(250/k)), 1, 3.14, int(4/k))
        pygame.draw.arc(screen, green, (int(x+82/k), int(y-505/k), int(400/k), int(150/k)), 1.6, 3.14, int(4/k)   )
        pygame.draw.arc(screen, green, (int(x-208/k), int(y-305/k), int(200/k), int(250/k)), 0, 2, int(4/k))
        pygame.draw.arc(screen, green, (int(x-378/k), int(y-485/k), int(401/k), int(150/k)), 0, 1.6 , int(4/k))

    #листочки

        #левая верхняя ветка
        surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
        surface1 = surface1.convert_alpha()
        ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
        surface2 = pygame.transform.rotate(surface1, -15)
        screen.blit(surface2, (x-158/k, y-480/k))

        surface2 = pygame.transform.rotate(surface1, -15)
        surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
        surface1 = surface1.convert_alpha()
        ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
        surface2 = pygame.transform.rotate(surface1, -15)
        screen.blit(surface2, (x-378/k+250/k, y-477/k))

        surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
        surface1 = surface1.convert_alpha()
        ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
        surface2 = pygame.transform.rotate(surface1, -15)
        screen.blit(surface2, (x-88/k,y-470/k))

        surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
        surface1 = surface1.convert_alpha()
        ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
        surface2 = pygame.transform.rotate(surface1, -15)
        screen.blit(surface2, (x-378/k+195/k, y-485/k))

        surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
        surface1 = surface1.convert_alpha()
        ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
        surface2 = pygame.transform.rotate(surface1, -15)
        screen.blit(surface2, (x-378/k+328/k, y-455/k))

        #правая верхняя ветка
        surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
        surface1 = surface1.convert_alpha()
        ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
        surface2 = pygame.transform.rotate(surface1, 15)
        screen.blit(surface2, (x+112/k, y-493/k))

        surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
        surface1 = surface1.convert_alpha()
        ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
        surface2 = pygame.transform.rotate(surface1, 15)
        screen.blit(surface2, (x+162/k, y-515/k))

        surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
        surface1 = surface1.convert_alpha()
        ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
        surface2 = pygame.transform.rotate(surface1, 15)
        screen.blit(surface2, (x+192/k, y-517/k))

        surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
        surface1 = surface1.convert_alpha()
        ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
        surface2 = pygame.transform.rotate(surface1, 15)
        screen.blit(surface2, (x+222/k, y-524/k))

        surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
        surface1 = surface1.convert_alpha()
        ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
        surface2 = pygame.transform.rotate(surface1, 15)
        screen.blit(surface2, (x+252/k, y-526/k))

        #правая нижняя ветка
        surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
        surface1 = surface1.convert_alpha()
        ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
        surface2 = pygame.transform.rotate(surface1, 15)
        screen.blit(surface2, (x+102/k, y-395/k))

        surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
        surface1 = surface1.convert_alpha()
        ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
        surface2 = pygame.transform.rotate(surface1, 15)
        screen.blit(surface2, (x+122/k, y-405/k))

        surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
        surface1 = surface1.convert_alpha()
        ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
        surface2 = pygame.transform.rotate(surface1, 15)
        screen.blit(surface2, (x+142/k, y-408/k))

        #левая нижняя ветка
        surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
        surface1 = surface1.convert_alpha()
        ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
        surface2 = pygame.transform.rotate(surface1, -15)
        screen.blit(surface2, (x-58/k, y-253/k))

        surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
        surface1 = surface1.convert_alpha()
        ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
        surface2 = pygame.transform.rotate(surface1, -15)
        screen.blit(surface2, (x-98/k, y-295/k))

        surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
        surface1 = surface1.convert_alpha()
        ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
        surface2 = pygame.transform.rotate(surface1, -15)
        screen.blit(surface2, (x-148/k, y-306/k))



def panda(x,y,k):

    #Туловище
        ellipse = pygame.draw.ellipse(screen, white, (x, y, 300/k, 200/k))

    #Средняя лапка
        surf1 = pygame.Surface((500/k, 500/k), pygame.SRCALPHA)
        surf2 = pygame.Surface((500/k, 500/k), pygame.SRCALPHA)
        pygame.draw.ellipse(surf1, black, (0/k, 75/k, 200/k, 400/k))
        pygame.draw.ellipse(surf2, black, (10/k, 0/k, 200/k, 90/k))
        surf3 = pygame.transform.rotate(surf1, 0)
        surf4 = pygame.transform.rotate(surf2, 60)
        surf3.blit(surf4, (0, 0), special_flags = pygame.BLEND_RGBA_MIN)
        screen.blit(surf3,(x+130/k,y-160/k))
        polygon(screen, black, [(x+70/k,y+250/k), (x+170/k,y+20/k),
                               (x+170/k,y+190/k), (x+130/k,y+280/k),(x+70/k,y+300/k)])

    #Правая лапка
        surf1 = pygame.Surface((500/k, 500/k), pygame.SRCALPHA)
        surf2 = pygame.Surface((500/k, 500/k), pygame.SRCALPHA)
        pygame.draw.ellipse(surf1, black, (0/k, 0/k, 200/k, 400/k))
        pygame.draw.ellipse(surf2, black, (120/k, 0/k, 200/k, 80/k))
        surf3 = pygame.transform.rotate(surf1, 20)
        surf4 = pygame.transform.rotate(surf2, 35)
        surf3.blit(surf4, (0, 0), special_flags = pygame.BLEND_RGBA_MIN)
        screen.blit(surf3,(x-88/k,y+42/k))

    #Левая лапка
        surf1 = pygame.Surface((700/k, 800/k), pygame.SRCALPHA)
        surf2 = pygame.Surface((700/k, 800/k), pygame.SRCALPHA)
        pygame.draw.ellipse(surf1, black, (0/k, 0/k, 200/k, 400/k))
        pygame.draw.ellipse(surf2, black, (150/k, 480/k, 80/k, 200/k))
        surf3 = pygame.transform.rotate(surf1, 40)
        surf4 = pygame.transform.rotate(surf2, -10)
        surf3.blit(surf4, (0, 0), special_flags = pygame.BLEND_RGBA_MIN)
        screen.blit(surf3,(x-200/k,y-450/k))
        polygon(screen, black, [(x+31/k,y+238/k), (x+65/k,y+210/k),
                               (x+65/k,y+100/k)])
    #Голова
        surf1 = pygame.Surface((400/k, 500/k), pygame.SRCALPHA)
        surf2 = pygame.Surface((400/k, 500/k), pygame.SRCALPHA)
        pygame.draw.ellipse(surf1, white, (0/k, 0/k, 210/k, 280/k))
        pygame.draw.ellipse(surf2, white, (0/k, 70/k, 280/k, 210/k))
        surf1.blit(surf2, (0, 0), special_flags = pygame.BLEND_RGBA_MIN)
        surf = pygame.transform.rotate(surf1,30)
        screen.blit(surf,(x-110/k, y-240/k))

    #Уши
        surf1 = pygame.Surface((400/k, 500/k), pygame.SRCALPHA)
        surf2 = pygame.Surface((400/k, 500/k), pygame.SRCALPHA)
        pygame.draw.ellipse(surf1, black, (0/k, 0/k, 50/k, 100/k))
        pygame.draw.ellipse(surf2, black, (10/k, 90/k, 50/k, 100/k))
        surf3 = pygame.transform.rotate(surf1,15)
        surf4 = pygame.transform.rotate(surf2, 0)
        surf3.blit(surf4, (0, 0), special_flags = pygame.BLEND_RGBA_MIN)
        screen.blit(surf3,(x+120/k, y-120/k))

        surf1 = pygame.Surface((400/k, 500/k), pygame.SRCALPHA)
        surf2 = pygame.Surface((400/k, 500/k), pygame.SRCALPHA)
        pygame.draw.ellipse(surf1, black, (0/k, 0/k, 50/k, 100/k))
        pygame.draw.ellipse(surf2, black, (10/k, 90/k, 50/k, 100/k))
        surf3 = pygame.transform.rotate(surf1,15)
        surf4 = pygame.transform.rotate(surf2, 0)
        surf3.blit(surf4, (0, 0), special_flags = pygame.BLEND_RGBA_MIN)
        surf5 = pygame.transform.rotate(surf3, -60)
        screen.blit(surf5,(x-372/k, y-134/k))

    #Нос и глаза
        pygame.draw.ellipse(screen, black, (x+25/k, y+130/k, 60/k, 40/k))
        pygame.draw.ellipse(screen, black, (x+70/k, y+50/k, 60/k, 60/k))
        pygame.draw.ellipse(screen, black, (x-10/k, y+25/k, 50/k, 60/k))



#большой бамбук
bambuk(800,750,0.8)
#детеныш
panda(730,790,2)
#панда
panda(920,600,0.9)
#бамбуки поменьше
bambuk(200,700,1.3)
bambuk(500,820,1.4)
bambuk(1220,620,1.3)

pygame.display.update()
clock = pygame.time.Clock()
finished = False

while not finished:
    clock.tick(FPS)
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            finished = True

pygame.quit()
# Out:
# <ipython-input-46-fd44f436ac07>:21: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   polygon(screen, green, [(x,y), (x+44/k,y),
# <ipython-input-46-fd44f436ac07>:23: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   polygon(screen, green, [(x,y-160/k), (x+44/k,y-160/k),
# <ipython-input-46-fd44f436ac07>:25: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   polygon(screen, green, [(x+42/k,y-435/k), (x+72/k, y-435/k),
# <ipython-input-46-fd44f436ac07>:27: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   polygon(screen, green, [(x+92/k,y-505/k), (x+112/k, y-505/k),
# <ipython-input-46-fd44f436ac07>:39: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
# <ipython-input-46-fd44f436ac07>:41: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
# <ipython-input-46-fd44f436ac07>:43: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   screen.blit(surface2, (x-158/k, y-480/k))
# <ipython-input-46-fd44f436ac07>:46: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
# <ipython-input-46-fd44f436ac07>:48: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
# <ipython-input-46-fd44f436ac07>:50: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   screen.blit(surface2, (x-378/k+250/k, y-477/k))
# <ipython-input-46-fd44f436ac07>:52: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
# <ipython-input-46-fd44f436ac07>:54: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
# <ipython-input-46-fd44f436ac07>:56: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   screen.blit(surface2, (x-88/k,y-470/k))
# <ipython-input-46-fd44f436ac07>:58: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
# <ipython-input-46-fd44f436ac07>:60: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
# <ipython-input-46-fd44f436ac07>:62: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   screen.blit(surface2, (x-378/k+195/k, y-485/k))
# <ipython-input-46-fd44f436ac07>:64: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
# <ipython-input-46-fd44f436ac07>:66: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
# <ipython-input-46-fd44f436ac07>:68: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   screen.blit(surface2, (x-378/k+328/k, y-455/k))
# <ipython-input-46-fd44f436ac07>:71: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
# <ipython-input-46-fd44f436ac07>:73: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
# <ipython-input-46-fd44f436ac07>:75: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   screen.blit(surface2, (x+112/k, y-493/k))
# <ipython-input-46-fd44f436ac07>:77: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
# <ipython-input-46-fd44f436ac07>:79: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
# <ipython-input-46-fd44f436ac07>:81: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   screen.blit(surface2, (x+162/k, y-515/k))
# <ipython-input-46-fd44f436ac07>:83: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
# <ipython-input-46-fd44f436ac07>:85: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
# <ipython-input-46-fd44f436ac07>:87: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   screen.blit(surface2, (x+192/k, y-517/k))
# <ipython-input-46-fd44f436ac07>:89: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
# <ipython-input-46-fd44f436ac07>:91: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
# <ipython-input-46-fd44f436ac07>:93: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   screen.blit(surface2, (x+222/k, y-524/k))
# <ipython-input-46-fd44f436ac07>:95: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
# <ipython-input-46-fd44f436ac07>:97: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
# <ipython-input-46-fd44f436ac07>:99: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   screen.blit(surface2, (x+252/k, y-526/k))
# <ipython-input-46-fd44f436ac07>:102: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
# <ipython-input-46-fd44f436ac07>:104: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
# <ipython-input-46-fd44f436ac07>:106: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   screen.blit(surface2, (x+102/k, y-395/k))
# <ipython-input-46-fd44f436ac07>:108: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
# <ipython-input-46-fd44f436ac07>:110: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
# <ipython-input-46-fd44f436ac07>:112: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   screen.blit(surface2, (x+122/k, y-405/k))
# <ipython-input-46-fd44f436ac07>:114: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
# <ipython-input-46-fd44f436ac07>:116: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
# <ipython-input-46-fd44f436ac07>:118: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   screen.blit(surface2, (x+142/k, y-408/k))
# <ipython-input-46-fd44f436ac07>:121: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
# <ipython-input-46-fd44f436ac07>:123: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
# <ipython-input-46-fd44f436ac07>:125: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   screen.blit(surface2, (x-58/k, y-253/k))
# <ipython-input-46-fd44f436ac07>:127: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
# <ipython-input-46-fd44f436ac07>:129: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
# <ipython-input-46-fd44f436ac07>:131: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   screen.blit(surface2, (x-98/k, y-295/k))
# <ipython-input-46-fd44f436ac07>:133: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surface1 = pygame.Surface([100/k,100/k], pygame.SRCALPHA, 32)
# <ipython-input-46-fd44f436ac07>:135: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15/k, 55/k))
# <ipython-input-46-fd44f436ac07>:137: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   screen.blit(surface2, (x-148/k, y-306/k))
# <ipython-input-46-fd44f436ac07>:144: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   ellipse = pygame.draw.ellipse(screen, white, (x, y, 300/k, 200/k))
# <ipython-input-46-fd44f436ac07>:147: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surf1 = pygame.Surface((500/k, 500/k), pygame.SRCALPHA)
# <ipython-input-46-fd44f436ac07>:148: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surf2 = pygame.Surface((500/k, 500/k), pygame.SRCALPHA)
# <ipython-input-46-fd44f436ac07>:149: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   pygame.draw.ellipse(surf1, black, (0/k, 75/k, 200/k, 400/k))
# <ipython-input-46-fd44f436ac07>:150: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   pygame.draw.ellipse(surf2, black, (10/k, 0/k, 200/k, 90/k))
# <ipython-input-46-fd44f436ac07>:154: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   screen.blit(surf3,(x+130/k,y-160/k))
# <ipython-input-46-fd44f436ac07>:155: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   polygon(screen, black, [(x+70/k,y+250/k), (x+170/k,y+20/k),
# <ipython-input-46-fd44f436ac07>:159: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surf1 = pygame.Surface((500/k, 500/k), pygame.SRCALPHA)
# <ipython-input-46-fd44f436ac07>:160: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surf2 = pygame.Surface((500/k, 500/k), pygame.SRCALPHA)
# <ipython-input-46-fd44f436ac07>:161: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   pygame.draw.ellipse(surf1, black, (0/k, 0/k, 200/k, 400/k))
# <ipython-input-46-fd44f436ac07>:162: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   pygame.draw.ellipse(surf2, black, (120/k, 0/k, 200/k, 80/k))
# <ipython-input-46-fd44f436ac07>:166: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   screen.blit(surf3,(x-88/k,y+42/k))
# <ipython-input-46-fd44f436ac07>:169: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surf1 = pygame.Surface((700/k, 800/k), pygame.SRCALPHA)
# <ipython-input-46-fd44f436ac07>:170: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surf2 = pygame.Surface((700/k, 800/k), pygame.SRCALPHA)
# <ipython-input-46-fd44f436ac07>:171: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   pygame.draw.ellipse(surf1, black, (0/k, 0/k, 200/k, 400/k))
# <ipython-input-46-fd44f436ac07>:172: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   pygame.draw.ellipse(surf2, black, (150/k, 480/k, 80/k, 200/k))
# <ipython-input-46-fd44f436ac07>:176: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   screen.blit(surf3,(x-200/k,y-450/k))
# <ipython-input-46-fd44f436ac07>:177: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   polygon(screen, black, [(x+31/k,y+238/k), (x+65/k,y+210/k),
# <ipython-input-46-fd44f436ac07>:180: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surf1 = pygame.Surface((400/k, 500/k), pygame.SRCALPHA)
# <ipython-input-46-fd44f436ac07>:181: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surf2 = pygame.Surface((400/k, 500/k), pygame.SRCALPHA)
# <ipython-input-46-fd44f436ac07>:182: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   pygame.draw.ellipse(surf1, white, (0/k, 0/k, 210/k, 280/k))
# <ipython-input-46-fd44f436ac07>:183: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   pygame.draw.ellipse(surf2, white, (0/k, 70/k, 280/k, 210/k))
# <ipython-input-46-fd44f436ac07>:186: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   screen.blit(surf,(x-110/k, y-240/k))
# <ipython-input-46-fd44f436ac07>:189: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surf1 = pygame.Surface((400/k, 500/k), pygame.SRCALPHA)
# <ipython-input-46-fd44f436ac07>:190: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surf2 = pygame.Surface((400/k, 500/k), pygame.SRCALPHA)
# <ipython-input-46-fd44f436ac07>:191: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   pygame.draw.ellipse(surf1, black, (0/k, 0/k, 50/k, 100/k))
# <ipython-input-46-fd44f436ac07>:192: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   pygame.draw.ellipse(surf2, black, (10/k, 90/k, 50/k, 100/k))
# <ipython-input-46-fd44f436ac07>:196: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   screen.blit(surf3,(x+120/k, y-120/k))
# <ipython-input-46-fd44f436ac07>:198: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surf1 = pygame.Surface((400/k, 500/k), pygame.SRCALPHA)
# <ipython-input-46-fd44f436ac07>:199: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   surf2 = pygame.Surface((400/k, 500/k), pygame.SRCALPHA)
# <ipython-input-46-fd44f436ac07>:200: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   pygame.draw.ellipse(surf1, black, (0/k, 0/k, 50/k, 100/k))
# <ipython-input-46-fd44f436ac07>:201: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   pygame.draw.ellipse(surf2, black, (10/k, 90/k, 50/k, 100/k))
# <ipython-input-46-fd44f436ac07>:206: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   screen.blit(surf5,(x-372/k, y-134/k))
# <ipython-input-46-fd44f436ac07>:209: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   pygame.draw.ellipse(screen, black, (x+25/k, y+130/k, 60/k, 40/k))
# <ipython-input-46-fd44f436ac07>:210: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   pygame.draw.ellipse(screen, black, (x+70/k, y+50/k, 60/k, 60/k))
# <ipython-input-46-fd44f436ac07>:211: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   pygame.draw.ellipse(screen, black, (x-10/k, y+25/k, 50/k, 60/k))
