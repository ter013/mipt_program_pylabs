# %%
import pygame, sys
from pygame.draw import *


pygame.init()

FPS = 30
screen = pygame.display.set_mode((1000, 1000))
screen.fill((255, 160, 122))


black=(0,0,0)
white=(255,255,255)
green=(0,100,0)

#стебли и ветки

#стебль(центральный)
polygon(screen, green, [(478,685), (522,685),
                               (522,535), (478,535)])
polygon(screen, green, [(478,525), (522,525),
                               (522,375), (478,375)])
polygon(screen, green, [(520,250), (550, 250),
                               (515,365), (485,365)])
polygon(screen, green, [(570,180), (590, 180),
                               (545,240), (525,240)])

#ветки(центральные)
pygame.draw.arc(screen, green, (530, 300, 200, 250), 1, 3.14, 4)
pygame.draw.arc(screen, green, (560, 180, 400, 150), 1.6, 3.14, 4)
pygame.draw.arc(screen, green, (270, 380, 200, 250), 0, 2, 4)
pygame.draw.arc(screen, green, (100, 200, 400, 150), 0, 1.6 , 4)

#стебель(левый)
polygon(screen, green, [(200,700), (220,700),
                               (220, 650), (200,650)])
polygon(screen, green, [(200,640), (220,640),
                               (220,590), (200,590)])
polygon(screen, green, [(222,540), (210, 540),
                               (204,580), (216,580)])
polygon(screen, green, [(228, 480), (220, 480),
                               (212,530), (220,530)])

#ветки(центральные)
pygame.draw.arc(screen, green, (225, 540, 100, 100), 1, 3.14, 3)
pygame.draw.arc(screen, green, (232, 370, 250, 250), 1.6, 3.14, 3)
pygame.draw.arc(screen, green, (95, 540, 100, 150), 0, 2, 3)
pygame.draw.arc(screen, green, (10, 410, 200, 220), 0, 1.6 , 3)

#листочки
surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15, 55))
surface2 = pygame.transform.rotate(surface1, -15)
screen.blit(surface2, (330, 205))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15, 55))
surface2 = pygame.transform.rotate(surface1, -15)
screen.blit(surface2, (360, 208))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15, 55))
surface2 = pygame.transform.rotate(surface1, -15)
screen.blit(surface2, (395, 215))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15, 55))
surface2 = pygame.transform.rotate(surface1, -15)
screen.blit(surface2, (300, 200))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15, 55))
surface2 = pygame.transform.rotate(surface1, -15)
screen.blit(surface2, (430, 230))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15, 55))
surface2 = pygame.transform.rotate(surface1, 15)
screen.blit(surface2, (590, 192))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15, 55))
surface2 = pygame.transform.rotate(surface1, 15)
screen.blit(surface2, (640, 170))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15, 55))
surface2 = pygame.transform.rotate(surface1, 15)
screen.blit(surface2, (670, 168))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15, 55))
surface2 = pygame.transform.rotate(surface1, 15)
screen.blit(surface2, (700, 161))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15, 55))
surface2 = pygame.transform.rotate(surface1, 15)
screen.blit(surface2, (730, 159))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15, 55))
surface2 = pygame.transform.rotate(surface1, 15)
screen.blit(surface2, (580, 290))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15, 55))
surface2 = pygame.transform.rotate(surface1, 15)
screen.blit(surface2, (600, 280))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15, 55))
surface2 = pygame.transform.rotate(surface1, 15)
screen.blit(surface2, (620, 277))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15, 55))
surface2 = pygame.transform.rotate(surface1, -15)
screen.blit(surface2, (420, 432))


surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15, 55))
surface2 = pygame.transform.rotate(surface1, -15)
screen.blit(surface2, (380, 390))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 15, 55))
surface2 = pygame.transform.rotate(surface1, -15)
screen.blit(surface2, (330, 379))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 8, 45))
surface2 = pygame.transform.rotate(surface1, 15)
screen.blit(surface2, (340, 346))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 8, 45))
surface2 = pygame.transform.rotate(surface1, 15)
screen.blit(surface2, (320, 348))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 8, 45))
surface2 = pygame.transform.rotate(surface1, 15)
screen.blit(surface2, (300, 357))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 8, 45))
surface2 = pygame.transform.rotate(surface1, 15)
screen.blit(surface2, (280, 369))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 8, 45))
surface2 = pygame.transform.rotate(surface1, 15)
screen.blit(surface2, (260, 385))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 8, 45))
surface2 = pygame.transform.rotate(surface1, 15)
screen.blit(surface2, (290, 520))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 8, 45))
surface2 = pygame.transform.rotate(surface1, 15)
screen.blit(surface2, (236, 530))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 8, 45))
surface2 = pygame.transform.rotate(surface1, 15)
screen.blit(surface2, (260, 520))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 8, 45))
surface2 = pygame.transform.rotate(surface1, -15)
screen.blit(surface2, (150, 443))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 8, 45))
surface2 = pygame.transform.rotate(surface1, -15)
screen.blit(surface2, (130, 427))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 8, 45))
surface2 = pygame.transform.rotate(surface1, -15)
screen.blit(surface2, (110, 417))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 8, 45))
surface2 = pygame.transform.rotate(surface1, -15)
screen.blit(surface2, (90, 408))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 8, 45))
surface2 = pygame.transform.rotate(surface1, -15)
screen.blit(surface2, (170, 470))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 8, 45))
surface2 = pygame.transform.rotate(surface1, -15)
screen.blit(surface2, (150, 558))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 8, 45))
surface2 = pygame.transform.rotate(surface1, -15)
screen.blit(surface2, (130, 542))

surface1 = pygame.Surface([100,100], pygame.SRCALPHA, 32)
surface1 = surface1.convert_alpha()
ellipse = pygame.draw.ellipse(surface1, green, (0, 0, 8, 45))
surface2 = pygame.transform.rotate(surface1, -15)
screen.blit(surface2, (110, 539))

#панда



#Туловище
ellipse = pygame.draw.ellipse(screen, white, (550, 500, 300, 200))

#Средняя лапка
surf1 = pygame.Surface((500, 500), pygame.SRCALPHA)
surf2 = pygame.Surface((500, 500), pygame.SRCALPHA)
pygame.draw.ellipse(surf1, black, (0, 75, 200, 400))
pygame.draw.ellipse(surf2, black, (10, 0, 200, 90))
surf3 = pygame.transform.rotate(surf1, 0)
surf4 = pygame.transform.rotate(surf2, 60)
surf3.blit(surf4, (0, 0), special_flags = pygame.BLEND_RGBA_MIN)
screen.blit(surf3,(680,340))
polygon(screen, black, [(620,750), (720,520),
                               (720,690), (680,780),(620,800)])

#Правая лапка
surf1 = pygame.Surface((500, 500), pygame.SRCALPHA)
surf2 = pygame.Surface((500, 500), pygame.SRCALPHA)
pygame.draw.ellipse(surf1, black, (0, 0, 200, 400))
pygame.draw.ellipse(surf2, black, (120, 0, 200, 80))
surf3 = pygame.transform.rotate(surf1, 20)
surf4 = pygame.transform.rotate(surf2, 35)
surf3.blit(surf4, (0, 0), special_flags = pygame.BLEND_RGBA_MIN)
screen.blit(surf3,(462,542))

#Левая лапка
surf1 = pygame.Surface((700, 800), pygame.SRCALPHA)
surf2 = pygame.Surface((700, 800), pygame.SRCALPHA)
pygame.draw.ellipse(surf1, black, (0, 0, 200, 400))
pygame.draw.ellipse(surf2, black, (150, 480, 80, 200))
surf3 = pygame.transform.rotate(surf1, 40)
surf4 = pygame.transform.rotate(surf2, -10)
surf3.blit(surf4, (0, 0), special_flags = pygame.BLEND_RGBA_MIN)
screen.blit(surf3,(350,50))
polygon(screen, black, [(581,738), (615,710),
                               (615,600)])
#Голова
surf1 = pygame.Surface((400, 500), pygame.SRCALPHA)
surf2 = pygame.Surface((400, 500), pygame.SRCALPHA)
pygame.draw.ellipse(surf1, white, (0, 0, 210, 280))
pygame.draw.ellipse(surf2, white, (0, 70, 280, 210))
surf1.blit(surf2, (0, 0), special_flags = pygame.BLEND_RGBA_MIN)
surf = pygame.transform.rotate(surf1,30)
screen.blit(surf,(440, 260))

#Уши
surf1 = pygame.Surface((400, 500), pygame.SRCALPHA)
surf2 = pygame.Surface((400, 500), pygame.SRCALPHA)
pygame.draw.ellipse(surf1, black, (0, 0, 50, 100))
pygame.draw.ellipse(surf2, black, (10, 90, 50, 100))
surf3 = pygame.transform.rotate(surf1,15)
surf4 = pygame.transform.rotate(surf2, 0)
surf3.blit(surf4, (0, 0), special_flags = pygame.BLEND_RGBA_MIN)
screen.blit(surf3,(670, 380))

surf1 = pygame.Surface((400, 500), pygame.SRCALPHA)
surf2 = pygame.Surface((400, 500), pygame.SRCALPHA)
pygame.draw.ellipse(surf1, black, (0, 0, 50, 100))
pygame.draw.ellipse(surf2, black, (10, 90, 50, 100))
surf3 = pygame.transform.rotate(surf1,15)
surf4 = pygame.transform.rotate(surf2, 0)
surf3.blit(surf4, (0, 0), special_flags = pygame.BLEND_RGBA_MIN)
surf5 = pygame.transform.rotate(surf3, -60)
screen.blit(surf5,(178, 366))

#Нос

pygame.draw.ellipse(screen, black, (575, 630, 60, 40))
pygame.draw.ellipse(screen, black, (620, 550, 60, 60))
pygame.draw.ellipse(screen, black, (540, 525, 50, 60))


pygame.display.update()
clock = pygame.time.Clock()
finished = False

while not finished:
    clock.tick(FPS)
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            finished = True

pygame.quit()
